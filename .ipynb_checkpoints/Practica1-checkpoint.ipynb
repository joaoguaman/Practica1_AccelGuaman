# %% [markdown]
# # Práctica 1 - Accel Guamán
# ## Análisis de Dataset de Pacientes de Parkinson
#
# Este dataset es una versión reducida de la base de datos brindada por el proyecto Parkinson’s Voice Initiative (PVI). Se puede acceder a la misma a través del portal synapse.org mediante la id ‘syn2321745’, la cual está registrada como Patient Voice Analysis (PVA) project.
#
# La base de datos incluye información de una serie de audios brindados para trabajar en la detección temprana de Parkinson. Esta version del dataset incluye la siguiente información de cada paciente: Referencia, Edad, Sexo, Años desde el 1er Sintoma, Diagnóstico en la Escala Hoeh-Yahr, Puntuación UPDRS, Estado del Tratamiento, Duración de la Grabación, Duración del Audio y Duración de Voz Usable.
#
# En esta práctica, se pretende añadir información acerca de rangos y porcentajes útiles para una representación gráfica.

# %%
import pandas as pd

# %%
# se lee el dataset
data = pd.read_excel("Dataset_Parkinson.xlsx")

data
# Out:
#      callref  current_age sex  years_since_first_symptom  hoehn_yahr  \
# 0      23336           63   F                          7           1
# 1      63225           76   F                          2           1
# 2      99762           51   F                         11           2
# 3     110232           67   M                          5           1
# 4     128887           58   F                         24           3
# ..       ...          ...  ..                        ...         ...
# 284  9735253           63   M                         16           4
# 285  9764151           70   F                          6           1
# 286  9823663           64   F                          7           1
# 287  9949188           65   M                          3           3
# 288  9997958           80   F                         11           1
#
#      pdrs_score  on_treatment_id  recording_duration  audio_duration  \
# 0            13             True                  28          21.879
# 1             5             True                  30          28.157
# 2            27            False                  28          24.555
# 3            14             True                  22          18.702
# 4            25             True                  23          15.834
# ..          ...              ...                 ...             ...
# 284          35             True                  30          28.430
# 285          14             True                  23          16.390
# 286          14             True                  17          14.915
# 287          25             True                  19          17.177
# 288          30             True                  15          10.856
#
#      voice_usable_duration
# 0                    13.80
# 1                    28.13
# 2                    20.90
# 3                    13.39
# 4                    13.04
# ..                     ...
# 284                  18.95
# 285                  16.36
# 286                  10.33
# 287                  11.95
# 288                   8.02
#
# [289 rows x 10 columns]

# %%
# se añade columna de ratio de audio usable por duración total de la grabación
data['usable_voice_ratio'] = (
    data['voice_usable_duration'] / data['recording_duration']
)

# %%
# se añaden rangos de edad de los pacientes 

rangos_edad = [40, 50, 60, 70, 80, 100]
labels_rangos_edad = ['40-49', '50-59', '60-69', '70-79', '80+']

data['age_group'] = pd.cut(data['current_age'], bins=rangos_edad, labels=labels_rangos_edad, right=False)

# %%
# se añaden rangos de años de convivencia con la enfermedad 

rangos_convivencia = [0, 8, 15, 22, 29, 36, 43, 50]
labels_rangos_convivencia = ['0-7', '8-14', '15-21', '22-28', '29-35', '36-42', '43-49']

data['years_group_with_Parkinson'] = pd.cut(
    data['years_since_first_symptom'],
    bins=rangos_convivencia,
    labels=labels_rangos_convivencia,
    right=False
)

# %%
# se añade una evaluación del nivel de parkinson en función de
# la escala Hoehn-Yahr y la puntuación PDRS
def parkinson_level(row):
    hoehn_yahr = row['hoehn_yahr']
    pdrs = row['pdrs_score']
    
    if hoehn_yahr <= 2 and pdrs <= 20:
        return 'Early'
    elif (2 < hoehn_yahr <= 3) or (20 < pdrs <= 40):
        return 'Medium'
    else:
        return 'Severe'

data['parkinson_level'] = data.apply(parkinson_level, axis=1)

# %%
data.style.format({
    'usable_voice_ratio': '{:.4%}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9f33">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9f33_level0_col0" class="col_heading level0 col0" >callref</th>
#       <th id="T_f9f33_level0_col1" class="col_heading level0 col1" >current_age</th>
#       <th id="T_f9f33_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_f9f33_level0_col3" class="col_heading level0 col3" >years_since_first_symptom</th>
#       <th id="T_f9f33_level0_col4" class="col_heading level0 col4" >hoehn_yahr</th>
#       <th id="T_f9f33_level0_col5" class="col_heading level0 col5" >pdrs_score</th>
#       <th id="T_f9f33_level0_col6" class="col_heading level0 col6" >on_treatment_id</th>
#       <th id="T_f9f33_level0_col7" class="col_heading level0 col7" >recording_duration</th>
#       <th id="T_f9f33_level0_col8" class="col_heading level0 col8" >audio_duration</th>
#       <th id="T_f9f33_level0_col9" class="col_heading level0 col9" >voice_usable_duration</th>
#       <th id="T_f9f33_level0_col10" class="col_heading level0 col10" >usable_voice_ratio</th>
#       <th id="T_f9f33_level0_col11" class="col_heading level0 col11" >age_group</th>
#       <th id="T_f9f33_level0_col12" class="col_heading level0 col12" >years_group_with_Parkinson</th>
#       <th id="T_f9f33_level0_col13" class="col_heading level0 col13" >parkinson_level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9f33_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9f33_row0_col0" class="data row0 col0" >23336</td>
#       <td id="T_f9f33_row0_col1" class="data row0 col1" >63</td>
#       <td id="T_f9f33_row0_col2" class="data row0 col2" >F</td>
#       <td id="T_f9f33_row0_col3" class="data row0 col3" >7</td>
#       <td id="T_f9f33_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_f9f33_row0_col5" class="data row0 col5" >13</td>
#       <td id="T_f9f33_row0_col6" class="data row0 col6" >True</td>
#       <td id="T_f9f33_row0_col7" class="data row0 col7" >28</td>
#       <td id="T_f9f33_row0_col8" class="data row0 col8" >21.879000</td>
#       <td id="T_f9f33_row0_col9" class="data row0 col9" >13.800000</td>
#       <td id="T_f9f33_row0_col10" class="data row0 col10" >49.2857%</td>
#       <td id="T_f9f33_row0_col11" class="data row0 col11" >60-69</td>
#       <td id="T_f9f33_row0_col12" class="data row0 col12" >0-7</td>
#       <td id="T_f9f33_row0_col13" class="data row0 col13" >Early</td>
#     </tr>
#     <tr>
#       <th id="T_f9f33_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9f33_row1_col0" class="data row1 col0" >63225</td>
#       <td id="T_f9f33_row1_col1" class="data row1 col1" >76</td>
#       <td id="T_f9f33_row1_col2" class="data row1 col2" >F</td>
#       <td id="T_f9f33_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_f9f33_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_f9f33_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_f9f33_row1_col6" class="data row1 col6" >True</td>
#       <td id="T_f9f33_row1_col7" class="data row1 col7" >30</td>
#       <td id="T_f9f33_row1_col8" class="data row1 col8" >28.157000</td>
#       <td id="T_f9f33_row1_col9" class="data row1 col9" >28.130000</td>
#       <td id="T_f9f33_row1_col10" class="data row1 col10" >93.7667%</td>
#       <td id="T_f9f33_row1_col11" class="data row1 col11" >70-79</td>
#       <td id="T_f9f33_row1_col12" class="data row1 col12" >0-7</td>
#       <td id="T_f9f33_row1_col13" class="data row1 col13" >Early</td>
#     </tr>
#     <tr>
#       <th id="T_f9f33_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9f33_row2_col0" class="data row2 col0" >99762</td>
#       <td id="T_f9f33_row2_col1" class="data row2 col1" >51</td>
#       <td id="T_f9f33_row2_col2" class="data row2 col2" >F</td>
#       <td id="T_f9f33_row2_col3" class="data row2 col3" >11</td>
#       <td id="T_f9f33_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_f9f33_row2_col5" class="data row2 col5" >27</td>
#       <td id="T_f9f33_row2_col6" class="data row2 col6" >False</td>
#       <td id="T_f9f33_row2_col7" class="data row2 col7" >28</td>
#       <td id="T_f9f33_row2_col8" class="data row2 col8" >24.555000</td>
#       <td id="T_f9f33_row2_col9" class="data row2 col9" >20.900000</td>
#       <td id="T_f9f33_row2_col10" class="data row2 col10" >74.6429%</td>
#       <td id="T_f9f33_row2_col11" class="data row2 col11" >50-59</td>
#       <td id="T_f9f33_row2_col12" class="data row2 col12" >8-14</td>
#       <td id="T_f9f33_row2_col13" class="data row2 col13" >Medium</td>
#     </tr>
#     <tr>
#       <th id="T_f9f33_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9f33_row3_col0" class="data row3 col0" >110232</td>
#       <td id="T_f9f33_row3_col1" class="data row3 col1" >67</td>
#       <td id="T_f9f33_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_f9f33_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_f9f33_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_f9f33_row3_col5" class="data row3 col5" >14</td>
#       <td id="T_f9f33_row3_col6" class="data row3 col6" >True</td>
#       <td id="T_f9f33_row3_col7" class="data row3 col7" >22</td>
#       <td id="T_f9f33_row3_col8" class="data row3 col8" >18.702000</td>
#       <td id="T_f9f33_row3_col9" class="data row3 col9" >13.390000</td>
#       <td id="T_f9f33_row3_col10" class="data row3 col10" >60.8636%</td>
#       <td id="T_f9f33_row3_col11" class="data row3 col11" >60-69</td>
#       <td id="T_f9f33_row3_col12" class="data row3 col12" >0-7</td>
#       <td id="T_f9f33_row3_col13" class="data row3 col13" >Early</td>
#     </tr>
#     <tr>
#       <th id="T_f9f33_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9f33_row4_col0" class="data row4 col0" >128887</td>
#       <td id="T_f9f33_row4_col1" class="data row4 col1" >58</td>
#       <td id="T_f9f33_row4_col2" class="data row4 col2" >F</td>
#       <td id="T_f9f33_row4_col3" class="data row4 col3" >24</td>
#       <td id="T_f9f33_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_f9f33_row4_col5" class="data row4 col5" >25</td>
#       <td id="T_f9f33_row4_col6" class="data row4 col6" >True</td>
#       <td id="T_f9f33_row4_col7" class="data row4 col7" >23</td>
#       <td id="T_f9f33_row4_col8" class="data row4 col8" >15.834000</td>
#       <td id="T_f9f33_row4_col9" class="data row4 col9" >13.040000</td>
#       <td id="T_f9f33_row4_col10" class="data row4 col10" >56.6957%</td>
#       <td id="T_f9f33_row4_col11" class="data row4 col11" >50-59</td>
#       <td id="T_f9f33_row4_col12" class="data row4 col12" >22-28</td>
#       <td id="T_f9f33_row4_col13" class="data row4 col13" >Medium</td>
#     </tr>
#     <tr>
#       <th id="T_f9f33_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9f33_row5_col0" class="data row5 col0" >149714</td>
#       <td id="T_f9f33_row5_col1" class="data row5 col1" >52</td>
#       <td id="T_f9f33_row5_col2" class="data row5 col2" >F</td>
#       <td id="T_f9f33_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_f9f33_row5_col4" class="data row5 col4" >3</td>
#       <td id="T_f9f33_row5_col5" class="data row5 col5" >26</td>
#       <td id="T_f9f33_row5_col6" class="data row5 col6" >True</td>
#       <td id="T_f9f33_row5_col7" class="data row5 col7" >14</td>
#       <td id="T_f9f33_row5_col8" class="data row5 col8" >7.128000</td>
#       <td id="T_f9f33_row5_col9" class="data row5 col9" >5.320000</td>
#       <td id="T_f9f33_row5_col10" class="data row5 col10" >38.0000%</td>
#       <td id="T_f9f33_row5_col11" class="data row5 col11" >50-59</td>
#       <td id="T_f9f33_row5_col12" class="data row5 col12" >0-7</td>
#       <td id="T_f9f33_row5_col13" class="data row5 col13" >Medium</td>
#     </tr>
#     <tr>
#       <th id="T_f9f33_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f9f33_row6_col0" class="data row6 col0" >194489</td>
#       <td id="T_f9f33_row6_col1" class="data row6 col1" >61</td>
#       <td id="T_f9f33_row6_col2" class="data row6 col2" >F</td>
#       <td id="T_f9f33_row6_col3" class="data row6 col3" >5</td>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
sns.countplot(data=data, x='age_group', hue='parkinson_level',
              order=sorted(data['age_group'].dropna().unique()))

plt.title('Nivel de Parkinson según grupo de edad')
plt.xlabel('Grupo de edad')
plt.ylabel('Cantidad de pacientes')

plt.show()

# %%
plt.figure()
sns.countplot(data=data, x='years_group_with_Parkinson', hue='parkinson_level',
              order=['0-7','8-14','15-21','22-28','29-35','36-42','43-49'])

plt.title('Nivel de Parkinson según años de convivencia con la enfermedad')
plt.xlabel('Años con Parkinson')
plt.ylabel('Cantidad de pacientes')

plt.xticks(rotation=45)
plt.show()
